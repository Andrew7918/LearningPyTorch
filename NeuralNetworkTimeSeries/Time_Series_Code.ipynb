# %% [markdown]
# This notebook will try to create a NN model that can predict stock data for Tesla stock (Closing price predictions).

# %%
# Delete this part if running Jupyter Notebook
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-937907f3-3af9-4a24-97eb-a90e697a6726" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-937907f3-3af9-4a24-97eb-a90e697a6726">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HistoricalQuotes.csv to HistoricalQuotes.csv
# {'HistoricalQuotes.csv': b'Date, Close/Last, Volume, Open, High, Low\n01/27/2021, $864.16, 27333960, $870.35, $891.5, $858.66\n01/26/2021, $883.09, 23131600, $891.38, $895.9, $871.6\n01/25/2021, $880.8, 41173400, $855, $900.4, $838.8201\n01/22/2021, $846.64, 20066500, $834.31, $848, $828.62\n01/21/2021, $844.99, 20598130, $855, $855.7199, $841.4201\n01/20/2021, $850.45, 25665880, $858.74, $859.5, $837.28\n01/19/2021, $844.55, 25366980, $837.8, $850, $833\n01/15/2021, $826.16, 38777600, $852, $859.9, $819.1\n01/14/2021, $845, 31266330, $843.39, $863, $838.75\n01/13/2021, $854.41, 33312500, $852.76, $860.47, $832\n01/12/2021, $849.44, 46270720, $831, $868, $827.34\n01/11/2021, $811.19, 59554150, $849.4, $854.43, $803.6222\n01/08/2021, $880.02, 75055530, $856, $884.49, $838.39\n01/07/2021, $816.04, 51498950, $777.63, $816.99, $775.2\n01/06/2021, $755.98, 44699970, $758.49, $774, $749.1\n01/05/2021, $735.11, 32245170, $723.66, $740.84, $719.2\n01/04/2021, $729.77, 48638190, $719.46, $744.4899, $717.1895\n12/31/2020, $705.67, 49649930, $699.99, $718.72, $691.12\n12/30/2020, $694.78, 42846020, $672, $696.6, $668.3603\n12/29/2020, $665.99, 22910810, $661, $669.9, $655\n12/28/2020, $663.69, 32278560, $674.51, $681.4, $660.8\n12/24/2020, $661.77, 22865570, $642.99, $666.09, $641\n12/23/2020, $645.98, 33172970, $632.2, $651.4999, $622.5701\n12/22/2020, $640.34, 51861640, $648, $649.88, $614.23\n12/21/2020, $649.86, 58045260, $666.24, $668.5, $646.07\n12/18/2020, $695, 222126200, $668.9, $695, $628.54\n12/17/2020, $655.9, 56270140, $628.19, $658.82, $619.5\n12/16/2020, $622.77, 42095810, $628.23, $632.5, $605\n12/15/2020, $633.25, 45223560, $643.28, $646.9, $623.8\n12/14/2020, $639.83, 52040650, $619, $642.7499, $610.2001\n12/11/2020, $609.99, 46474970, $615.01, $624, $596.8\n12/10/2020, $627.07, 67083150, $574.37, $627.75, $566.34\n12/09/2020, $604.48, 71291190, $653.69, $654.32, $588\n12/08/2020, $649.88, 64265030, $625.505, $651.28, $618.5\n12/07/2020, $641.76, 56309710, $604.9197, $648.7856, $603.05\n12/04/2020, $599.04, 29401310, $591.01, $599.04, $585.5\n12/03/2020, $593.38, 42552000, $590.02, $598.97, $582.43\n12/02/2020, $568.82, 47775650, $556.44, $571.54, $541.21\n12/01/2020, $584.76, 40382830, $597.59, $597.85, $572.05\n11/30/2020, $567.6, 63003050, $602.21, $607.8, $554.51\n11/27/2020, $585.76, 37561080, $581.16, $598.78, $578.45\n11/25/2020, $574, 48930160, $550.06, $574, $545.37\n11/24/2020, $555.38, 53648490, $540.4, $559.99, $526.2\n11/23/2020, $521.85, 50260300, $503.5, $526, $501.79\n11/20/2020, $489.61, 32911920, $497.99, $502.5, $489.06\n11/19/2020, $499.27, 62475350, $492, $508.6112, $487.57\n11/18/2020, $486.64, 78044020, $448.35, $496, $443.5001\n11/17/2020, $441.61, 61188280, $460.17, $462, $433.01\n11/16/2020, $408.09, 26838640, $408.93, $412.45, $404.0868\n11/13/2020, $408.5, 19830350, $410.85, $412.5319, $401.66\n11/12/2020, $411.76, 19940500, $415.05, $423, $409.52\n11/11/2020, $417.13, 17357720, $416.45, $418.695, $410.58\n11/10/2020, $410.36, 30284220, $420.09, $420.09, $396.0301\n11/09/2020, $421.26, 34833030, $439.5, $452.5, $421\n11/06/2020, $429.95, 21706010, $436.1, $436.57, $424.28\n11/05/2020, $438.09, 28414520, $428.3, $440, $424.0001\n11/04/2020, $420.98, 32143060, $430.62, $435.4, $417.1\n11/03/2020, $423.9, 34351720, $409.73, $427.77, $406.69\n11/02/2020, $400.51, 29021120, $394, $406.9799, $392.3\n10/30/2020, $388.04, 42587640, $406.8954, $407.5915, $379.11\n10/29/2020, $410.83, 22655310, $409.96, $418.06, $406.46\n10/28/2020, $406.02, 25451410, $416.48, $418.6, $406\n10/27/2020, $424.68, 22686510, $423.76, $430.5, $420.1\n10/26/2020, $420.28, 28239160, $411.63, $425.76, $410\n10/23/2020, $420.63, 33716980, $421.84, $422.8859, $407.3801\n10/22/2020, $425.79, 39993190, $441.92, $445.23, $424.51\n10/21/2020, $422.64, 32370460, $422.7, $432.95, $421.25\n10/20/2020, $421.94, 31656290, $431.75, $431.75, $419.0501\n10/19/2020, $430.83, 36287840, $446.24, $447, $428.87\n10/16/2020, $439.67, 32775880, $4 ...

# %% [markdown]
# # 1. Imports

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import confusion_matrix,classification_report,roc_curve, roc_auc_score
from sklearn.preprocessing import MinMaxScaler

# %%
plt.rcParams.update({'font.size': 13})

# %% [markdown]
# # 2. Dataset and DatasetLoader Classes

# %%
'''
# Manual way to get the time lag
l = [1,2,3,4,5]
input = 2 #so given the last 2 days, predict the next day
output = 1

x_out = []
y_out = []
for counter in range(0,len(l)-input-output+1):
  x_out.append(l[counter : counter + input])
  y_out.append(l[counter+input : counter + input + output])
print(x_out)
print(y_out)
'''

# %%
#An important thing to note is that __getitem__() returns a specific type for a single data point (like a tensor, numpy array etc.)
# The get item needs to return other things now, since we need to set a time lag
class TeslaDataset(Dataset):
  '''
  Create dataset from CSV. Will use this to create train dataset and test dataset. 
  '''
  def __init__(self, df,target,n_in,n_out,dataset_type, normalize = False, normalizer = None):
    '''
    Parameters:
    df -- dataframe to convert into dataset
    target -- target column to use for time series
    n_in -- rolling window size || n_in = 3 means predictions made on last 3 days
    n_out -- output size || n_out =3 means that model will predict next 3 days.
    normalize -- Whether or not to normalize
    dataset_type -- "train" or "test"
    normalizer -- Only required if dataset_type is "test" and normalize == True. Will use the train normalizer for transforming, no refitting is used.
    '''

    df,X,Y,dropped = self.preprocess(df,target,n_in,n_out,dataset_type,normalize,normalizer)

    self.df = df
    # Take tensors from output 
    self.X = torch.from_numpy(X)
    self.Y = torch.from_numpy(Y)
    self.dropped = dropped

  def __len__(self):
    return len(self.X)

  def __getitem__(self,idx):
    if torch.is_tensor(idx):
        idx = idx.tolist()
    return (self.X[idx],self.Y[idx])
  
  def preprocess(self, df,target,n_in,n_out,dataset_type, normalize = False, normalizer = None):
    '''
    Main function to preprocess dataframe
    '''
    # Convert the datatypes to floats
    df = self.convert_to_float(df)

    # Normalize data (or not)
    if normalize == True:
      if dataset_type == "train":
        self.normalizer, target_data  = self.normalize(df[target].values)
      elif dataset_type == "test":
        self.normalizer = normalizer
        target_data = self.normalizer.transform(df[target].values.reshape(-1,1))
    elif normalize == False:
      self.normalizer = None
      target_data = df[target].values

    # Convert data into time lag
    X,Y,dropped = self.convert_to_time_lag(target_data, n_in,n_out)

    return df,X,Y,dropped

  ####################
  # Helper Functions #
  ####################
  def convert_to_float(self,df):
    corrections = ['Close','Open','High','Low']
    for c in corrections:
      df[c] = df[c].apply(lambda s : float(str(s)[2:]))
    return df
  
  def normalize(self,data):
    normalizer = MinMaxScaler()
    data = normalizer.fit_transform(data.reshape(-1,1))
    return normalizer,data
  

  def get_normalizer(self):
    return self.normalizer


  def convert_to_time_lag(self,data, n_in=1, n_out=1):
    '''
    Function to convert into time lag, using pandas way, inspired by:
    https://machinelearningmastery.com/how-to-develop-deep-learning-models-for-univariate-time-series-forecasting/

    data - a list of numbers
    n_in - number of days to use as the window size
    n_out - target number of days to predict
    '''
    df = pd.DataFrame(data)
    cols = list()
    # input sequence (t-n, ... t-1)
    # this way it append the shifts from df.shift(n_in),df.shift(n_in-1), onwards.
    # So the first row of the first column would be at 0-n_in days
    for i in range(n_in, 0, -1):
      cols.append(df.shift(i).values) #shifts down
    # output sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
      cols.append(df.shift(-i).values) #shifts up
    
    # Concat and drop na
    df = pd.DataFrame(np.concatenate(cols, axis=1))
    dropped_df = df.dropna()
    dropped_index = df[~df.index.isin(dropped_df.index)].index

    # Just extract the x and y values
    x = dropped_df.iloc[:,:n_in].values
    y = dropped_df.iloc[:,n_in:].values
    return x,y,dropped_index

# %% [markdown]
# # 3. Model Definition Class

# %%
# Defining the model
class forecast_model_simple(nn.Module):
  '''
  This is the class for the forecasting model. Will use simple 3-layer neural network. [7,10,1]
  '''
  def __init__(self,n_in,n_out):
    super(forecast_model_simple,self).__init__()
    self.fc1 = nn.Linear(in_features = n_in,out_features = 10)
    self.fc2 = nn.Linear(in_features = 10, out_features = n_out)

  def forward(self,x):
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

# %% [markdown]
# #4. Model Training Function

# %%
def fit(model,num_epochs,dataloader,criterion,optimizer):
  '''
  Fitting the model based on the train set. Specify the dataloader used, as well as the size of the dataset.

  model - model to be fitted
  dataloader - dataloader to use
  num_epochs - number of epochs
  '''
  # Train the model
  dataset_length = len(dataloader.dataset)
  losses = []
  for i in range(num_epochs):
    print("-"*25)
    print(f"Currently training for epoch {i+1}.")
    running_loss = 0
    for idx,data in enumerate(dataloader):
      # Get the data
      # Shape of data = (batch_size, dim(x))
      x,y = data 
      if idx == 0:
        print(x.size)
      y = y.float()

      # Zero the gradients
      optimizer.zero_grad()

      # Forward Pass
      y_hat = model(x.float())
      # Get Loss, use RMSE
      loss = torch.sqrt(criterion(y_hat,y))
      # Backward Pass and Optimize
      loss.backward() #Will automatically get gradients for the batch
      optimizer.step()

      # Get the loss and multiply it by the number of samples in the batch
      running_loss += loss.item() * x.shape[0] 

    epoch_loss = running_loss / dataset_length
    print(f"Epoch {i+1} loss : {epoch_loss}")
    losses.append(epoch_loss)
  print("Training finished.")
  return losses

# %%
def plot_model_loss(train_loss,num_epochs):
  fig,ax = plt.subplots(figsize = (10,6))
  plt.plot(train_loss,label='Training loss')
  plt.xticks(np.arange(0,num_epochs,1))
  ax.set_xticklabels(np.arange(1,num_epochs+1,1))
  plt.title('Loss curve for training')
  plt.ylabel('Loss')
  plt.xlabel('Epochs')
  plt.legend()
  plt.show()

# %% [markdown]
# If we need to save the model:

# %%
# Save Model
#torch.save(model.state_dict(),"LR_model")

# %%
# Load Model
#model = LogisticRegression()
#model.load_state_dict(torch.load(PATH))

# %% [markdown]
# #5. Model Evaluation function

# %% [markdown]
# Use torch.Tensor.item() to get a Python number from a tensor containing a single value:

# %%
def predict(model,dataloader, normalize = False,normalizer = None):
  '''
  Parameters: 
  model -- model for prediction
  dataloader -- loads data for model to predict on
  normalize -- True or False
  normalizer -- Only required if normalize is true. Uses this to inverse transform predictions, should use the normalizer for training datset
  '''
  # Will need to validate by filling in with ground truth value.
  length = len(dataloader.dataset)
  with torch.no_grad():
    running_loss = 0
    actual_predictions = np.array([])
    for idx,data in enumerate(dataloader):
      x,y = data
      # Get predictions
      pred = model(x.type(torch.float32))
      
      # Sum up the loss
      running_loss += torch.sqrt(criterion(y,pred)).item()

      # Append predictions to output
      actual_predictions = np.append(actual_predictions,pred.item())

  # Undo the normalization on the output to get actual prediction values
  if normalize == True:
    actual_predictions = normalizer.inverse_transform(actual_predictions.reshape(-1,1))

  # Get the average of running loss
  loss = running_loss/length
  return loss,actual_predictions 
#loss, pred = predict(model,testloader)

# %%
def plot_results(pred_dates,true_dates,pred,true,normalize,save_path):
  if normalize == True:
    norma = "Normalized"
  else:
    norma = "UnNormalized"
  fig,ax = plt.subplots(figsize = (12,8))
  plt.plot(pred_dates, pred , label = 'Predictions')
  plt.plot(true_dates,true,label = 'Actual',alpha=0.5)
  

  plt.title(f"Model Predictions with {save_path}")
  plt.xlabel('Date')
  plt.ylabel('Closing Price')
  plt.legend()
  plt.show()
  plt.draw()
  fig.savefig(save_path)
  #plt.savefig(save_path)

# %%
def evaluate(model,dataloader,test_dataset,train_dataset,df,normalize = False,save_path = None):
  '''
  Function to evaluate model. Will produce classification report, Confusion Matrix, and finally will show ROC-AUC.

  Parameters:
  model -- model to evaluate
  dataloader -- the dataloader used. Should be test loader
  test_dataset -- test dataset used
  train_dataset -- training dataset
  df -- dataframe used for the time series prediction
  normalize -- True or False
  '''
  if normalize == True:
    # We only use the train dataset's normalizer
    normalizer = train_dataset.get_normalizer()
  else: 
    normalizer = None


  # Prepare predictions

  # Get model predictions. 
  loss,pred = predict(model,dataloader,normalize, normalizer)
  print(f"The average RMSE of predictions is : {loss}")
  # Convert to 1 dimension
  pred = pred.squeeze()
  # Also get corresponding dates for the predictions
  pred_dates = pd.to_datetime(test_dataset.df.iloc[max(test_dataset.dropped)+1:,:]['Date'])
 
  # Prepare ground truth data

  true = np.append(train_dataset.df[target].values,test_dataset.df[target].values)
  true = true.squeeze()  
  # Make the dates into datetime for ground truth
  true_dates = pd.to_datetime(df.Date)

  # Plotting part
  plot_results(pred_dates,true_dates,pred,true,normalize,save_path)

  #####################################################
  # Plot only prediction period
  alt = save_path + " (magnified)"
  plot_results(pred_dates = pred_dates,
               true_dates = pd.to_datetime(test_dataset.df['Date']),
               pred = pred,
               true = test_dataset.df[target].values,
               normalize = normalize,
               save_path =alt
               )
  return loss

# %% [markdown]
# # 6. Main Function

# %%
def main(df_path,window_size,out_size,target,test_size,training_batch_size,test_batch_size,normalize,num_epochs,lr,save_path,optim_type,weight_decay = 0):
  '''
  Main function to test models out. Encapsulates entire process from reading in dataframe, preparing datasets, creating model, etc.

  Parameters:
 
  df_path -- path to dataframe
  window_size -- rolling window size || window_size = 3 means predictions made on last 3 days
  out_size -- output size || out_size = 3 means that model will predict next 3 days.
  target -- target column to use for time series prediction
  test_size -- fraction of df to use as test data
  training_batch_size,test_batch_size -- # of samples to include in each batch respectively
  normalize -- Whether or not to normalize (True or False)
  num_epochs -- Number of epochs to train for
  lr -- learning rate
  save_path -- path to save the graph of model predictions (the plot)
  optim_type -- optimizer type. At the moment on can use "ADAM" or "SGD"
  weight_decay -- L2 Regularization. If none is to be used set this to 0
  '''
  df = pd.read_csv(df_path)
  df.columns= ['Date','Close','Volume','Open','High','Low']

  # Reorder dataframe to ascending order (from earliest to most recent dates)
  df = df.iloc[::-1,:]
  df.reset_index(drop=True,inplace=True)
  # Split dataframe up into train and test
  df_train, df_test = tts(df, test_size=test_size, random_state=2021, shuffle=False)

  # Create datasets
  train_dataset = TeslaDataset(df = df_train,
                              target = target,
                              n_in = window_size,
                              n_out = out_size,
                              normalize = normalize,
                              dataset_type='train'
                              )
  test_dataset = TeslaDataset(df = df_test,
                              target = target,
                              n_in = window_size,
                              n_out = out_size, 
                              normalize = normalize,
                              normalizer = train_dataset.get_normalizer(),
                              dataset_type='test'
                              )
  # Testing to see if creation of dataset is successful
  print(train_dataset.__getitem__(234))


  # Create Dataloaders
  trainloader = DataLoader(train_dataset,
                          batch_size = training_batch_size,
                          shuffle = True,
                          num_workers = 2,
                          drop_last=False
                          )
  testloader = DataLoader(test_dataset,
                          batch_size = 
                          test_batch_size,shuffle = False,
                          num_workers = 2,
                          drop_last=False
                          )

  # Additionally here, I will do 10 runs each time, and then we get the average loss from those 10 runs
  running_avg_loss = 0
  for runs in range(10):
    print("#"*25)
    print(f"Starting Run {runs+1}")
    # Create the model
    model = forecast_model_simple(n_in = window_size, n_out = out_size)

    if optim_type == 'SGD':
      # use stochastic gradient descent here
      optimizer = optim.SGD(model.parameters(),lr = lr,momentum = 0.9,weight_decay = weight_decay)
    elif optim_type == 'ADAM':
      # use ADAM optimizer here
      optimizer = optim.Adam(model.parameters(),lr = lr,weight_decay= weight_decay)

    # Define the loss function, use MSE here then later sqrt for RMSE
    criterion = nn.MSELoss()

    train_loss = fit(model,num_epochs,trainloader,criterion,optimizer)
    #plot_model_loss(train_loss,num_epochs)

    # See what the latest run of the model yields graphically
    if runs != 9:
      
      loss, pred = predict(model,testloader)
    else:
      loss = evaluate(model,
              testloader,
              test_dataset,
              train_dataset,
              df,
              normalize= normalize,
              save_path = save_path
              )
    running_avg_loss += loss
  print(f"FOR THIS VERSION OF THE MODEL, THE AVERAGE LOSS OVER 10 RUNS IS {running_avg_loss/10}")

# %%
df_path = "/content/HistoricalQuotes.csv"
window_size = 7 
out_size = 1 
target = 'Close'

test_size=0.3
training_batch_size = 16
test_batch_size = 1

normalize = True
num_epochs = 10
lr = 0.0001
optim_type = "SGD"
weight_decay = 0
save_path = "Normalized_v1"

main(df_path,
     window_size,
     out_size,
     target,
     test_size,
     training_batch_size,
     test_batch_size,
     normalize,
     num_epochs,
     lr,
     save_path,
     optim_type,
     weight_decay
     )
# Out:
# (tensor([0.2901, 0.3038, 0.3453, 0.3443, 0.3536, 0.3630, 0.3572],
#        dtype=torch.float64), tensor([0.3566], dtype=torch.float64))
# #########################
# Starting Run 1
# -------------------------
# Currently training for epoch 1.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <built-in method size of Tensor object at 0x7fad9ae33ee8>
# Epoch 1 loss : 0.6881476062386205
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9abb1990>
# Epoch 2 loss : 0.6043026167686253
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9b35b708>
# Epoch 3 loss : 0.5148188268565477
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9b15f318>
# Epoch 4 loss : 0.4197676700094472
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9ac6d048>
# Epoch 5 loss : 0.31908228863840515
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9abc9798>
# Epoch 6 loss : 0.21563392638887366
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9ae291b0>
# Epoch 7 loss : 0.12695598348259107
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9ae5a7e0>
# Epoch 8 loss : 0.08877704065778981
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9abc9798>
# Epoch 9 loss : 0.08134451474423267
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9aeaebd0>
# Epoch 10 loss : 0.07636140005607626
# Training finished.
# #########################
# Starting Run 2
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9abe11b0>
# Epoch 1 loss : 0.5738718666528401
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9ac55e58>
# Epoch 2 loss : 0.46654309594931265
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9abc7288>
# Epoch 3 loss : 0.3673379535124013
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9ae5ad80>
# Epoch 4 loss : 0.2898516950604572
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9ac92b40>
# Epoch 5 loss : 0.23148399969942238
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9abc7288>
# Epoch 6 loss : 0.1955337610001968
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9ae5a8b8>
# Epoch 7 loss : 0.17733042811638158
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9abc0c18>
# Epoch 8 loss : 0.16931105618209533
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9ae33a68>
# Epoch 9 loss : 0.1642124381777351
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9ac551f8>
# Epoch 10 loss : 0.16000549040001644
# Training finished.
# #########################
# Starting Run 3
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9ac925a0>
# Epoch 1 loss : 0.4312482507605302
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9ac925e8>
# Epoch 2 loss : 0.31256056970808
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9abc9558>
# Epoch 3 loss : 0.2077984454225348
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9abb1ab0>
# Epoch 4 loss : 0.14656664529981547
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9abc9558>
# Epoch 5 loss : 0.12798810223420098
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9ae29630>
# Epoch 6 loss : 0.12137902603064848
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9ae31120>
# Epoch 7 loss : 0.11612222822770919
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9ae31480>
# Epoch 8 loss : 0.11118045348665534
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9ac6da68>
# Epoch 9 loss : 0.10618789255346259
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9b136ca8>
# Epoch 10 loss : 0.10105994500611958
# Training finished.
# #########################
# Starting Run 4
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9b136c60>
# Epoch 1 loss : 1.0790552353695273
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9b7cae58>
# Epoch 2 loss : 0.9738924281002455
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9ae29828>
# Epoch 3 loss : 0.8706726112682159
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9ae29168>
# Epoch 4 loss : 0.7737292876505469
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9b7ca090>
# Epoch 5 loss : 0.6803105920894195
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9abb1990>
# Epoch 6 loss : 0.5868429413376466
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9abe14c8>
# Epoch 7 loss : 0.49418709589087445
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9b334e10>
# Epoch 8 loss : 0.40202662969344816
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9ac925e8>
# Epoch 9 loss : 0.3088784989830558
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9abdd9d8>
# Epoch 10 loss : 0.223156018647231
# Training finished.
# #########################
# Starting Run 5
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9aeae948>
# Epoch 1 loss : 0.7726192841267968
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9b0150d8>
# Epoch 2 loss : 0.6579017860120167
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9aeae090>
# Epoch 3 loss : 0.5375016485799096
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9ae31480>
# Epoch 4 loss : 0.4162591092919321
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9b0150d8>
# Epoch 5 loss : 0.2937450059423185
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9abc0c18>
# Epoch 6 loss : 0.18406413986562864
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9b136ca8>
# Epoch 7 loss : 0.12385179327472669
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9ae4ec18>
# Epoch 8 loss : 0.11225380712706655
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9ae29090>
# Epoch 9 loss : 0.10723891562741736
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9ac925a0>
# Epoch 10 loss : 0.10292295003373782
# Training finished.
# #########################
# Starting Run 6
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9abc9558>
# Epoch 1 loss : 0.5891593728785657
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9ada6c60>
# Epoch 2 loss : 0.45569565598970146
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9ac551f8>
# Epoch 3 loss : 0.3178938876846017
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9b7cae58>
# Epoch 4 loss : 0.19292616687322917
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9abb1990>
# Epoch 5 loss : 0.12243049058134005
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9abc7288>
# Epoch 6 loss : 0.10975716421615068
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9b15f288>
# Epoch 7 loss : 0.10497232949365468
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9ae5a288>
# Epoch 8 loss : 0.10069077777371527
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9ada6c60>
# Epoch 9 loss : 0.09684989219467481
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9ae2e4c8>
# Epoch 10 loss : 0.09291259601746325
# Training finished.
# #########################
# Starting Run 7
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9abc7ab0>
# Epoch 1 loss : 0.8828340142760724
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9b7ca090>
# Epoch 2 loss : 0.7450959106877412
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9ae33ee8>
# Epoch 3 loss : 0.6191497160040814
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9ae29c60>
# Epoch 4 loss : 0.5017783271502576
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9ae29708>
# Epoch 5 loss : 0.388501795396652
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9abc7ab0>
# Epoch 6 loss : 0.2814465122855774
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9ae31120>
# Epoch 7 loss : 0.18934391694701783
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9ae33a68>
# Epoch 8 loss : 0.13382339586655118
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9b334e10>
# Epoch 9 loss : 0.1162075282541238
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9b7d69d8>
# Epoch 10 loss : 0.10934217785670501
# Training finished.
# #########################
# Starting Run 8
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9ae5ae10>
# Epoch 1 loss : 0.5812585570719476
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9b15ffc0>
# Epoch 2 loss : 0.4801650472172883
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9b15f120>
# Epoch 3 loss : 0.3807817148534875
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9ae29708>
# Epoch 4 loss : 0.28865952875030393
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9abb1c60>
# Epoch 5 loss : 0.20245314340024026
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9abc0c18>
# Epoch 6 loss : 0.12667505085059108
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9b136ca8>
# Epoch 7 loss : 0.08499454080342428
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9abb1318>
# Epoch 8 loss : 0.07535673309654611
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9ac6db88>
# Epoch 9 loss : 0.07177453058467032
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9ae29558>
# Epoch 10 loss : 0.06874778917916034
# Training finished.
# #########################
# Starting Run 9
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9b0c8ea0>
# Epoch 1 loss : 1.1278370444234502
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9ae5a288>
# Epoch 2 loss : 1.0130134197612648
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9ac6da68>
# Epoch 3 loss : 0.9041300008171483
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9ae4ea68>
# Epoch 4 loss : 0.8006437460399601
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9ae33ee8>
# Epoch 5 loss : 0.7011761965413388
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9ac55d38>
# Epoch 6 loss : 0.6036828655400047
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9ae4ec18>
# Epoch 7 loss : 0.5064606937991127
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9ae31fc0>
# Epoch 8 loss : 0.409040685922112
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9abd8f30>
# Epoch 9 loss : 0.3096020149420819
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9b015fc0>
# Epoch 10 loss : 0.21188138520826738
# Training finished.
# #########################
# Starting Run 10
# -------------------------
# Currently training for epoch 1.
# <built-in method size of Tensor object at 0x7fad9abc0c18>
# Epoch 1 loss : 0.6156408859745043
# -------------------------
# Currently training for epoch 2.
# <built-in method size of Tensor object at 0x7fad9ae29c60>
# Epoch 2 loss : 0.41887876517576267
# -------------------------
# Currently training for epoch 3.
# <built-in method size of Tensor object at 0x7fad9aeae948>
# Epoch 3 loss : 0.22022725992944747
# -------------------------
# Currently training for epoch 4.
# <built-in method size of Tensor object at 0x7fad9abb1c60>
# Epoch 4 loss : 0.09713234159098064
# -------------------------
# Currently training for epoch 5.
# <built-in method size of Tensor object at 0x7fad9abdd9d8>
# Epoch 5 loss : 0.08543758070441623
# -------------------------
# Currently training for epoch 6.
# <built-in method size of Tensor object at 0x7fad9abc7ab0>
# Epoch 6 loss : 0.08261697348079365
# -------------------------
# Currently training for epoch 7.
# <built-in method size of Tensor object at 0x7fad9ae2e4c8>
# Epoch 7 loss : 0.07998343638956411
# -------------------------
# Currently training for epoch 8.
# <built-in method size of Tensor object at 0x7fad9aeae948>
# Epoch 8 loss : 0.07778290525351564
# -------------------------
# Currently training for epoch 9.
# <built-in method size of Tensor object at 0x7fad9ae5a8b8>
# Epoch 9 loss : 0.07555403625187666
# -------------------------
# Currently training for epoch 10.
# <built-in method size of Tensor object at 0x7fad9b7cae58>
# Epoch 10 loss : 0.07322980456685038
# Training finished.
# The average RMSE of predictions is : 1.0852211634651803
# FOR THIS VERSION OF THE MODEL, THE AVERAGE LOSS OVER 10 RUNS IS 1.841047557622467

# %% [markdown]
# The general structure of the neural network used for training is a 2 layer neural net:
#
# Input (7) - Dense(10) - RELU - Dense(1) - Output(1)
#
# Experiment Results (Unnormalized):
# -----------------------------------------
# 1. Parameters :
#   * SGD with momentum
#   * 10 epochs
#   * unnormalized
#   * RMSE
#   * lr - 0.0001
#
#   We get an averaged test loss of 11.559852639605994.
#
#
#
# 2. Parameters :
#   * SGD with momentum
#   * 10 epochs
#   * unnormalized
#   * RMSE
#   * lr - 0.00001
#
#   We get an averaged test loss of 15.655083044918916
#
#
# 3. Parameters :
#   * SGD with momentum
#   * 10 epochs
#   * unnormalized
#   * RMSE
#   * weight decay (L2) - 0.01
#   * lr - 0.0001
#
#   We get an averaged test loss of 12.245280777388832
#
# 4. Parameters :
#   * ADAM
#   * 10 epochs
#   * unnormalized
#   * RMSE
#   * lr - 0.0001
#
#   We get an averaged test loss of 125.97540926785484
#
# 5. Parameters :
#   * ADAM
#   * 20 epochs
#   * unnormalized
#   * RMSE
#   * lr - 0.001
#
#   We get an averaged test loss of 14.332120224583054
#
#
# 6. Parameters :
#   * ADAM
#   * 20 epochs
#   * unnormalized
#   * RMSE
#   * lr - 0.0001
#   * weight decay (L2) - 0.01
#
#   We get an averaged test loss of 46.89324450016691
#
# 7. Parameters :
#   * ADAM
#   * 20 epochs
#   * unnormalized
#   * RMSE
#   * lr - 0.001
#   * weight decay (L2) - 0.01
#
#   We get an averaged test loss of 14.525197051236958

# %% [markdown]
# Experiment Results (Normalized):
#
# 1. Parameters :
#   * SGD with momentum
#   * 10 epochs
#   * unnormalized
#   * RMSE
#   * lr - 0.0001
# We get an averaged test loss of 1.841047557622467 (Note that this is not very reflective of model's power since RMSE calculated based on normalized values). In reality the loss is much higher than the unnormalized version, with the same parameters. You can also see this by comparing UnNormalized_v1.png and Normalized_v1.png

# %% [markdown]
# # 7. Closing Remarks

# %% [markdown]
# Even though some of the experiments showed promising results, with low RMSE scores, the model's predictive powers are not actually that good.
#
# Some of the models with low RMSE scores are actually just predicting the value at time “t+1” using the ground truth value at time “t” as its prediction. Take the period between 2020 and 2021 as an example from the figure below:

# %% [markdown]
# ![UnNormalized_v1 (magnified).png](data:image/png;base64,...)

# %% [markdown]
# The predictions for that time period are off by a day or two, and it's highly likely that this is caused by the persistence model.
#
# [This article](https://towardsdatascience.com/how-not-to-use-machine-learning-for-time-series-forecasting-avoiding-the-pitfalls-19f9d7adf424) talks a lot about such pitfalls, and alternative ways to measure model's predictive performance. But for now, this is out of the scope for this notebook.
